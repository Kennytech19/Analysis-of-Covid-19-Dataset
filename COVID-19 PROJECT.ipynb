# %% [markdown]
# COVID - 19 PROJECT

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Olowoselu\Documents\Bluetooth Exchange Folder\country_wise_latest.csv')
data
# Out:
#              Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0               Afghanistan      36263    1269      25198     9796        106
# 1                   Albania       4880     144       2745     1991        117
# 2                   Algeria      27973    1163      18837     7973        616
# 3                   Andorra        907      52        803       52         10
# 4                    Angola        950      41        242      667         18
# 5       Antigua and Barbuda         86       3         65       18          4
# 6                 Argentina     167416    3059      72575    91782       4890
# 7                   Armenia      37390     711      26665    10014         73
# 8                 Australia      15303     167       9311     5825        368
# 9                   Austria      20558     713      18246     1599         86
# 10               Azerbaijan      30446     423      23242     6781        396
# ...

# %%
data.shape
# Out:
# (187, 15)

# %%
data.info
# Out:
# <bound method DataFrame.info of              Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0               Afghanistan      36263    1269      25198     9796        106
# 1                   Albania       4880     144       2745     1991        117
# 2                   Algeria      27973    1163      18837     7973        616
# 3                   Andorra        907      52        803       52         10
# 4                    Angola        950      41        242      667         18
# 5       Antigua and Barbuda         86       3         65       18          4
# 6                 Argentina     167416    3059      72575    91782       4890
# 7                   Armenia      37390     711      26665    10014         73
# 8                 Australia      15303     167       9311     5825        368
# 9                   Austria      20558     713      18246     1599         86
# 10               Azerbaijan      30446     423      23242     6781        396
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
data.count()
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
#to drop the unwanted columns
data.drop(columns = ['1 week change', '1 week % increase', 'Confirmed last week', 'Deaths / 100 Recovered', 'Deaths / 100 Cases', 'Recovered / 100 Cases', 'New recovered', 'New deaths', 'Active', 'New cases'], inplace = True)

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered             WHO Region
# 0    Afghanistan      36263    1269      25198  Eastern Mediterranean
# 1        Albania       4880     144       2745                 Europe
# 2        Algeria      27973    1163      18837                 Africa
# 3        Andorra        907      52        803                 Europe
# 4         Angola        950      41        242                 Africa

# %%
data.count()
# Out:
# Country/Region    187
# Confirmed         187
# Deaths            187
# Recovered         187
# WHO Region        187
# dtype: int64

# %% [markdown]
# # Show the number of comfirmed, Deaths and Recovered cases in each Region

# %%
data.rename(columns = {'Country/Region':'Region'}, inplace = True)

# %%
data.head()
# Out:
#         Region  Confirmed  Deaths  Recovered             WHO Region
# 0  Afghanistan      36263    1269      25198  Eastern Mediterranean
# 1      Albania       4880     144       2745                 Europe
# 2      Algeria      27973    1163      18837                 Africa
# 3      Andorra        907      52        803                 Europe
# 4       Angola        950      41        242                 Africa

# %%
data.groupby('Region').sum().head()
# Out:
#              Confirmed  Deaths  Recovered
# Region
# Afghanistan      36263    1269      25198
# Albania           4880     144       2745
# Algeria          27973    1163      18837
# Andorra            907      52        803
# Angola             950      41        242

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Deaths'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                148011
# Brazil             87618
# United Kingdom     45844
# Mexico             44022
# Italy              35112
# India              33408
# France             30212
# Spain              28432
# Peru               18418
# Iran               15912
# Name: Deaths, dtype: int64

# %%
data.groupby('Region')['Recovered'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# Brazil          1846641
# US              1325804
# India            951166
# Russia           602249
# Chile            319954
# Mexico           303810
# South Africa     274925
# Peru             272547
# Iran             255144
# Pakistan         241026
# Name: Recovered, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum().head()
# Out:
#              Confirmed  Recovered
# Region
# Afghanistan      36263      25198
# Albania           4880       2745
# Algeria          27973      18837
# Andorra            907        803
# Angola             950        242

# %% [markdown]
# # Remove all the records where confirmed cases is less than 10

# %%
data = data[~(data.Confirmed < 10)]
data.head()
# Out:
#         Region  Confirmed  Deaths  Recovered             WHO Region
# 0  Afghanistan      36263    1269      25198  Eastern Mediterranean
# 1      Albania       4880     144       2745                 Europe
# 2      Algeria      27973    1163      18837                 Africa
# 3      Andorra        907      52        803                 Europe
# 4       Angola        950      41        242                 Africa

# %% [markdown]
# # In which Region maximum number of comfirmed cases were recorded

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head()
# Out:
# Region
# US              4290259
# Brazil          2442375
# India           1480073
# Russia           816680
# South Africa     452529
# Name: Confirmed, dtype: int64

# %% [markdown]
# # In which Region Minimum number of Deaths were recorded

# %%
data.groupby('Region')['Deaths'].sum().sort_values().head(20)
# Out:
# Region
# Fiji                                0
# Holy See                            0
# Grenada                             0
# Laos                                0
# Greenland                           0
# Cambodia                            0
# Vietnam                             0
# Bhutan                              0
# Timor-Leste                         0
# Mongolia                            0
# Dominica                            0
# Saint Vincent and the Grenadines    0
# Saint Lucia                         0
# Papua New Guinea                    0
# Eritrea                             0
# Saint Kitts and Nevis               0
# Seychelles                          0
# Western Sahara                      1
# Liechtenstein                       1
# Burundi                             1
# Name: Deaths, dtype: int64

# %% [markdown]
# # How many Confirmed, Deaths and Recovered cases were reported in India?

# %%
data.groupby(data['Region']=='India').sum()
# Out:
#         Confirmed  Deaths  Recovered
# Region
# False    15000412  620628    8516921
# True      1480073   33408     951166

# %%
data[data['Region'] == 'India']
# Out:
#    Region  Confirmed  Deaths  Recovered       WHO Region
# 79  India    1480073   33408     951166  South-East Asia

# %% [markdown]
# # Sort the entire data wrt No. of Comfirmed cases in ascending order.

# %%
data.sort_values(by = ['Confirmed'], ascending = True).head(10)
# Out:
#                     Region  Confirmed  Deaths  Recovered       WHO Region
# 183         Western Sahara         10       1          8           Africa
# 75                Holy See         12       0         12           Europe
# 68               Greenland         14       0         13           Europe
# 140  Saint Kitts and Nevis         17       0         15         Americas
# 49                Dominica         18       0         18         Americas
# 94                    Laos         20       0         19  Western Pacific
# 69                 Grenada         23       0         23         Americas
# 168            Timor-Leste         24       0          0  South-East Asia
# 141            Saint Lucia         24       0         22         Americas
# 59                    Fiji         27       0         18  Western Pacific

# %% [markdown]
# # Sort the entire data wrt No. of Recovered cases in descending order

# %%
data.sort_values(by = 'Recovered', ascending = False)
# Out:
#                                Region  Confirmed  Deaths  Recovered  \
# 23                             Brazil    2442375   87618    1846641
# 173                                US    4290259  148011    1325804
# 79                              India    1480073   33408     951166
# 138                            Russia     816680   13334     602249
# 35                              Chile     347923    9187     319954
# 111                            Mexico     395489   44022     303810
# 154                      South Africa     452529    7067     274925
# 132                              Peru     389717   18418     272547
# 81                               Iran     293606   15912     255144
# 128                          Pakistan     274289    5842     241026
# 145                      Saudi Arabia     268934    2760     222936
# 172                            Turkey     227019    5630     210469
# 85                              Italy     246286   35112     198593
# ...
